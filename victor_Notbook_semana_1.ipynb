# %% [markdown]
# <a href="https://colab.research.google.com/github/joserivera18xx-sudo/notebook--agroindustrial_2026-1/blob/main/victor_Notbook_semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ENTRADA: entra ancho y alto de la madera en metros
ancho = input("ingressa el ancho de la madera en metros")
ancho= float(ancho)
alto = input("ingresa el alto de la ventana en metros")
alto = float(alto)

#PROCESO: calcula la longitud de la madera (lm) en pies
# y el area del vidrio en metros cuadrados
lm= 2 * (ancho + alto ) * 3.25
av = 2 * (ancho + alto )

#SALIDA: sale la longitud de la madera en pies
# el area del vidrio es ",av, " metros cuadrados
print("longitud de la madera en es ", lm , "pies de longitud")
print("el area del vidrio es ",av, " metros cuadrados")
# Out:
# ingressa el ancho de la madera en metros1
# ingresa el alto de la ventana en metros2
# longitud de la madera en es  19.5 pies de longitud
# el area del vidrio es  6.0  metros cuadrados
